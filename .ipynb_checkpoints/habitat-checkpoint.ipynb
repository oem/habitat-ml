# %% [markdown]
# # getting the data
#
# We will fetch the data from the habitat api and store it in a file.
# The reason we are not directly importing the json into our data structure is to have reproducible steps and data when training and especially evaluating our model.

# %% [markdown]
# ### fetching the data from the api

# %%
import urllib.request, json
with urllib.request.urlopen("https://habitat-lifesupport.herokuapp.com/measurements?token=Gafdiweq931") as url:
    data = json.loads(url.read())

# %% [markdown]
# ### saving to file

# %%
with open("measurements.json", "w") as file:
    json.dump(data, file)

# %% [markdown]
# ### loading data from file into a panda dataframe

# %%
import pandas as pd
with open("measurements.json") as file:
    data = pd.read_json(file)

# %% [markdown]
# ### create a test set

# %%
from sklearn.model_selection import train_test_split
train_set, test_set = train_test_split(data, test_size=0.2, random_state=42)

# %% [markdown]
# ### split into features and label

# %%
feature_attributes = ['temperature', 'measuredAt']
label_attributes = ['humidity']
X_train, y_train = train_set[feature_attributes], train_set[label_attributes]

# %% [markdown]
# ### explore the data

# %%
X_train.describe()
# Out:
#        temperature
# count  3969.000000
# mean     19.349257
# std       2.074631
# min      15.200000
# 25%      17.600000
# 50%      19.000000
# 75%      21.200000
# max      24.500000

# %%
y_train.describe()
# Out:
# count    3969.000000
# mean       61.351600
# std         6.660233
# min        29.500000
# 25%        57.100000
# 50%        62.100000
# 75%        66.200000
# max        79.900000
# Name: humidity, dtype: float64

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(12,9))
plt.xlabel("time", fontsize=16)
plt.ylabel("humidity", fontsize=16)
x = data['measuredAt']
y = data['humidity']


plt.tick_params(axis="both", which="both", bottom="off", top="off",    
                labelbottom="on", left="off", right="off", labelleft="on")    
  
plt.plot(x, y)
plt.show()

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(train_set, figsize=(12, 8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x10f007c50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10ef2ca90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x10eed4438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10edbda90>]], dtype=object)
